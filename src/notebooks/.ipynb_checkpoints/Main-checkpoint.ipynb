# %%
import sys
import os

# %%
# !python ../2_train_retriever/get_llm_feedback_scores.py
# Out:
# Hello:  /Users/zia-mac/Documents/projects/information-retrieval/FinSeer/src
# start running the LLM feedback scorar
# loading TheFinAI/StockLLM model
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:00<00:00,  4.17it/s]
# model loaded.
# iterating over dataset
# processing dataset acl18
# 1016617 : toggling  1  in  2912
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# /Users/zia-mac/Documents/projects/information-retrieval/FinSeer/src/notebooks/../2_train_retriever/get_llm_feedback_scores.py:80: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   outputs_tensor = torch.tensor(outputs).to(input_ids.device)
# prob:  0.1640625
# prob:  0.244140625
# ...
